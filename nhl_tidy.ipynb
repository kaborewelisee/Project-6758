# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import nhl_dataset
import nhl_tidy_data

# %%
df = pd.read_csv('./data/df.csv')
df.head(10)
# Out:
# /var/folders/qq/3fs3sqzs3rxgn4rv1b11z90c0000gn/T/ipykernel_41508/1252621019.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/df.csv')
#         game_start_time         game_end_time    season     game_id  team_id  \
# 0  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594        8
# 1  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594        8
# 2  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594        8
# 3  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594       10
# 4  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594       10
# 5  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594        8
# 6  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594        8
# 7  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594        8
# 8  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594        8
# 9  2017-01-08T00:00:00Z  2017-01-08T02:50:13Z  20162017  2016020594       10
#
#              team_name team_tri_code         team_link event_type  \
# 0   Montréal Canadiens           MTL   /api/v1/teams/8       SHOT
# 1   Montréal Canadiens           MTL   /api/v1/teams/8       GOAL
# 2   Montréal Canadiens           MTL   /api/v1/teams/8       SHOT
# 3  Toronto Maple Leafs           TOR  /api/v1/teams/10       SHOT
# 4  Toronto Maple Leafs           TOR  /api/v1/teams/10       SHOT
# 5   Montréal Canadiens           MTL   /api/v1/teams/8       GOAL
# 6   Montréal Canadiens           MTL   /api/v1/teams/8       SHOT
# 7   Montréal Canadiens           MTL   /api/v1/teams/8       SHOT
# 8   Montréal Canadiens           MTL   /api/v1/teams/8       SHOT
# 9  Toronto Maple Leafs           TOR  /api/v1/teams/10       GOAL
#
#    coordinates_x  coordinates_y       shooter_name        goalie_name  \
# 0           36.0          -23.0         Shea Weber  Frederik Andersen
# 1           63.0            0.0     Max Pacioretty  Frederik Andersen
# 2           79.0            0.0   Michael McCarron  Frederik Andersen
# 3          -69.0          -16.0        Leo Komarov        Carey Price
# 4          -63.0          -12.0        Nazem Kadri        Carey Price
# 5           74.0           -9.0   Artturi Lehkonen  Frederik Andersen
# 6           66.0           37.0     Max Pacioretty  Frederik Andersen
# 7           69.0           -2.0  Alexander Radulov  Frederik Andersen
# 8           44.0           36.0      Mark Barberio  Frederik Andersen
# 9          -76.0           -1.0        Tyler Bozak        Carey Price
#
#     shot_type goal_empty_net goal_strength_code  period  team_home  \
# 0  Wrist Shot            NaN                NaN       1      False
# 1  Wrist Shot          False               EVEN       1      False
# 2      Tip-In            NaN                NaN       1      False
# 3  Wrist Shot            NaN                NaN       1       True
# 4  Wrist Shot            NaN                NaN       1       True
# 5   Snap Shot          False               EVEN       1      False
# 6   Snap Shot            NaN                NaN       1      False
# 7   Snap Shot            NaN                NaN       1      False
# 8   Snap Shot            NaN                NaN       1      False
# 9   Snap Shot          False                PPG       1       True
#
#   team_rink_side_right  event_id
# 0                False         7
# 1                False         8
# 2                False        34
# 3                 True        12
# 4                 True        13
# 5                False        14
# 6                False        17
# 7                False        18
# 8                False        21
# 9                 True        24
